# %%
import plotly.express as px
import numpy as np

from okami.demo import Demo
from okami.src.domain.entities.sensor import Sensor
from okami.src.services.plotting import plots

# %%
vertix1 = (0, 0)
vertix2 = (0, 3)
vertix3 = (4, 4)
vertix4 = (5, 0)

vertices = [vertix1, vertix2, vertix3, vertix4]

cache_size = 10

sensor1 = Sensor(id = "sensors_1", x = 0.25, y = 0.5, z = 1.5, cache_size = cache_size)
sensor2 = Sensor(id = "sensors_2", x = 2.5, y = 1.75, z = 2.5, cache_size = cache_size)
sensor3 = Sensor(id = "sensors_3", x = 2.25, y = 3.5, z = 1.5, cache_size = cache_size)
sensor4 = Sensor(id = "sensors_4", x = 4, y = 0.25, z = 1.5, cache_size = cache_size)
sensors = [sensor1, sensor2, sensor3, sensor4]

demo = Demo(vertices = vertices, sensors = sensors, res = 0.25, num_sources = 2, time_steps = 60)

# %%
# plots.plot_room(room = demo.room)

# %%
for i in range(30):
    demo.run_cycle()

    print(" ------ INTERPOLATION ------")
    fig = px.imshow(demo.grid_map, range_color = (400, demo.real_map.max().max()))
    fig.update_yaxes(autorange = True)
    fig.show()

    # if demo.variogram is not None:
    #     x = np.arange(0, 2.5, 0.1)
    #     y = [demo.variogram.variance(i) for i in x]
    #     fig = px.line(x = x, y = y)
    #     fig.show()
    
    print(" ------ REAL ------")
    fig = px.imshow(demo.real_map)
    fig.update_yaxes(autorange = True)
    fig.show()
# Out:
# 2022-01-01 12:00:00
#  ------ INTERPOLATION ------
#  ------ REAL ------
# 2022-01-01 12:00:30
#  ------ INTERPOLATION ------
#  ------ REAL ------
# 2022-01-01 12:01:00
#  ------ INTERPOLATION ------
#  ------ REAL ------
# 2022-01-01 12:01:30
#  ------ INTERPOLATION ------
#  ------ REAL ------
# 2022-01-01 12:02:00
#  ------ INTERPOLATION ------
#  ------ REAL ------
# 2022-01-01 12:02:30
#  ------ INTERPOLATION ------
#  ------ REAL ------
# 2022-01-01 12:03:00
#  ------ INTERPOLATION ------
#  ------ REAL ------
# 2022-01-01 12:03:30
#  ------ INTERPOLATION ------
#  ------ REAL ------
# 2022-01-01 12:04:00
#  ------ INTERPOLATION ------
#  ------ REAL ------
# 2022-01-01 12:04:30
#  ------ INTERPOLATION ------
#  ------ REAL ------
# 2022-01-01 12:05:00
#  ------ INTERPOLATION ------
#  ------ REAL ------
# 2022-01-01 12:05:30
#  ------ INTERPOLATION ------
#  ------ REAL ------
# 2022-01-01 12:06:00
#  ------ INTERPOLATION ------
#  ------ REAL ------
# 2022-01-01 12:06:30
# ...

# %%
for i, source in enumerate(demo.fake_data):
    print(f"Source {i}")
    print(f"X: {source[0, demo.ts]} ----- Y: {source[1, demo.ts]} ----- VALUE: {source[2, demo.ts]}")

for i, sensor in enumerate(demo.sensors):
    print(f"Sensor {i}")
    print(f"X: {sensor.x} ----- Y: {sensor.y} ----- VALUE: {sensor.value}")

# %%
def trunc(x):
    if x > 1000:
        return 3
    if x <= 1000 and x > 600:
        return 2
    if x < 600:
        return 1

# %%
px.imshow(demo.grid_map.applymap(trunc), color_continuous_scale = "viridis", range_color = (1, 3))

# %%
px.imshow(demo.real_map.applymap(trunc), color_continuous_scale = "viridis", range_color = (1, 3))
